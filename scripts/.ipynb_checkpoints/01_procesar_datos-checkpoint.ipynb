# %% [markdown]
# # Procesamiento de Datos — Desconectados
# ## HackODS UNAM 2026 · Abejas Astutas
#
# Carga, limpia e integra las tres fuentes oficiales en un único DataFrame
# por entidad federativa.
#
# | Fuente | Archivo | Variable clave |
# |--------|---------|---------------|
# | INEGI — ENDUTIH 2024 | `tr_endutih_hogares_anual_2024.csv` | Hogares con/sin internet |
# | CONEVAL 2020 | `pobreza_estatal_2020.csv` + `Concentrado_indicadores_de_pobreza_2020.xlsx` | Pobreza total y extrema + población |
# | SEP — Media Superior 2019-2024 | `MEDIA_SUPERIOR_*.csv` | Abandono y calidad educativa |
#
# **Decisión estadística:** normalizamos **por estado** (no por México total).
# `% por estado` = severidad del problema *dentro* de cada entidad → permite comparar estados justamente.

# %%
import pandas as pd
import warnings
warnings.filterwarnings("ignore")

# Rutas relativas desde scripts/ al resto del repo
RAW = "../data raw"
OUT = "../datos"

import pathlib
pathlib.Path(OUT).mkdir(exist_ok=True)
print("Directorios listos.")
# Out:
# Directorios listos.

# %% [markdown]
# ## 1 · Conectividad por entidad — ENDUTIH 2024

# %%
# Cargamos solo las columnas necesarias para ahorrar memoria
hogares = pd.read_csv(
    f"{RAW}/tr_endutih_hogares_anual_2024.csv",
    encoding="latin1",
    usecols=["CVE_ENT", "P4_4", "FAC_HOG", "DOMINIO"],
)
cat_ent = pd.read_csv(f"{RAW}/tc_endutih_entidad.csv", encoding="latin1")

print(f"Hogares en muestra: {len(hogares):,}")
print(f"P4_4 — 1=tiene internet, 2=no tiene:")
print(hogares["P4_4"].value_counts())
# Out:
# Hogares en muestra: 58,080
# P4_4 — 1=tiene internet, 2=no tiene:
# P4_4
# 1    42638
# 2    15442
# Name: count, dtype: int64

# %%
# Porcentaje ponderado de hogares con internet por entidad (factor de expansión FAC_HOG)
internet_ent = (
    hogares.groupby("CVE_ENT")
    .apply(lambda g: round(
        g.loc[g["P4_4"] == 1, "FAC_HOG"].sum() / g["FAC_HOG"].sum() * 100, 1
    ))
    .reset_index(name="internet_pct")
    .merge(cat_ent, on="CVE_ENT")
)

# Indicadores nacionales (para value boxes del dashboard)
total_fac  = hogares["FAC_HOG"].sum()
media_nac  = round(hogares.loc[hogares["P4_4"]==1, "FAC_HOG"].sum() / total_fac * 100, 1)
pct_urbano = round(
    hogares.loc[(hogares["P4_4"]==1) & (hogares["DOMINIO"]=="U"), "FAC_HOG"].sum() /
    hogares.loc[hogares["DOMINIO"]=="U", "FAC_HOG"].sum() * 100, 1)
pct_rural  = round(
    hogares.loc[(hogares["P4_4"]==1) & (hogares["DOMINIO"]=="R"), "FAC_HOG"].sum() /
    hogares.loc[hogares["DOMINIO"]=="R", "FAC_HOG"].sum() * 100, 1)

print(f"Media nacional : {media_nac:.1f}%")
print(f"Zona urbana    : {pct_urbano:.1f}%")
print(f"Zona rural     : {pct_rural:.1f}%")
print(f"Brecha urb-rur : {pct_urbano - pct_rural:.1f} pp")
print()
print(internet_ent.sort_values("internet_pct")[["NOM_ENT","internet_pct"]].to_string())
# Out:
# Media nacional : 73.6%
# Zona urbana    : 79.7%
# Zona rural     : 48.5%
# Brecha urb-rur : 31.2 pp
#
#                             NOM_ENT  internet_pct
# 6                           Chiapas          50.7
# 19                           Oaxaca          55.5
# 11                         Guerrero          58.9
# 28                         Tlaxcala          61.5
# 20                           Puebla          61.8
# 9                           Durango          63.9
# 29  Veracruz de Ignacio de la Llave          64.0
# 23                 San Luis PotosÃ­          65.5
# 17                          Nayarit          66.9
# 15             MichoacÃ¡n de Ocampo          67.7
# 12                          Hidalgo          70.2
# 3                          Campeche          71.5
# 26                          Tabasco          71.7
# 30                         YucatÃ¡n          73.9
# 16                          Morelos          74.4
# 27                       Tamaulipas          74.9
# ...

# %% [markdown]
# ## 2 · Pobreza por entidad — CONEVAL 2020

# %%
# pobreza_estatal_2020.csv: pre-generado desde el Excel de CONEVAL
# Columnas: CVE_ENT, nom_estado, pobreza_pct_2020
pobreza = pd.read_csv(f"{RAW}/pobreza_estatal_2020.csv", encoding="utf-8")
pobreza = pobreza.rename(columns={"pobreza_pct_2020": "pobreza_pct"})
pobreza["CVE_ENT"] = pobreza["CVE_ENT"].astype(int)

print(f"Entidades: {len(pobreza)}")
print(pobreza.sort_values("pobreza_pct", ascending=False)
      [["CVE_ENT","nom_estado","pobreza_pct"]].to_string())
# Out:
# Entidades: 32
#     CVE_ENT                       nom_estado  pobreza_pct
# 6         7                          Chiapas         74.4
# 11       12                         Guerrero         65.6
# 19       20                           Oaxaca         63.8
# 20       21                           Puebla         63.4
# 29       30  Veracruz de Ignacio de la Llave         60.8
# 28       29                         Tlaxcala         58.3
# 26       27                          Tabasco         53.0
# 16       17                          Morelos         52.6
# 14       15                           México         50.8
# 3         4                         Campeche         48.5
# 30       31                          Yucatán         47.8
# 12       13                          Hidalgo         45.7
# 15       16              Michoacán de Ocampo         45.6
# 22       23                     Quintana Roo         44.8
# 23       24                  San Luis Potosí         44.6
# ...

# %% [markdown]
# ## 3 · Abandono escolar en Media Superior — SEP 2019-2024

# %%
# Tendencia histórica nacional + suroeste + norte
ciclos = {
    2020: "MEDIA SUPERIOR 2019-2020.csv",
    2021: "MEDIA SUPERIOR 2020-2021.csv",
    2022: "MEDIA SUPERIOR 2021-2022.csv",
    2023: "MEDIA SUPERIOR 2022-2023.csv",
    2024: "MEDIA_SUPERIOR 2023-2024.csv",
}

abandono_hist = []

for yr, fn in ciclos.items():
    df = pd.read_csv(
        f"{RAW}/{fn}", encoding="latin1",
        usecols=["ENTIDAD", "C_NOM_ENT", "ALUMNOS", "EXISTENTES"],
    )
    nac = (df["ALUMNOS"].sum() - df["EXISTENTES"].sum()) / df["ALUMNOS"].sum() * 100
    sur = df[df["ENTIDAD"].isin([7, 12, 20])]
    sur_pct = (sur["ALUMNOS"].sum() - sur["EXISTENTES"].sum()) / sur["ALUMNOS"].sum() * 100
    nor = df[df["ENTIDAD"].isin([2, 5, 19])]
    nor_pct = (nor["ALUMNOS"].sum() - nor["EXISTENTES"].sum()) / nor["ALUMNOS"].sum() * 100

    abandono_hist.append({
        "anio":                     yr,
        "Nacional":                 round(nac, 2),
        "Suroeste (Chis/Gro/Oax)": round(sur_pct, 2),
        "Norte (B.C./Coah/N.L.)":  round(nor_pct, 2),
    })

tendencia = pd.DataFrame(abandono_hist)
print("Tendencia abandono escolar Media Superior:")
print(tendencia.to_string(index=False))
# Out:
# Tendencia abandono escolar Media Superior:
#  anio  Nacional  Suroeste (Chis/Gro/Oax)  Norte (B.C./Coah/N.L.)
#  2020      8.02                     8.13                    4.27
#  2021      5.83                     5.65                    6.11
#  2022      6.16                     5.71                    8.48
#  2023      9.57                     8.43                    9.77
#  2024      8.95                     8.18                    6.60

# %%
# Abandono y titulación por entidad — ciclo más reciente (2023-24)
ms_latest = pd.read_csv(
    f"{RAW}/MEDIA_SUPERIOR 2023-2024.csv", encoding="latin1",
    usecols=["ENTIDAD", "C_NOM_ENT", "ALUMNOS", "EXISTENTES",
             "EGRESADOS", "TITULADOS", "DOCENTES"],
)

calidad_ent = (
    ms_latest.groupby(["ENTIDAD", "C_NOM_ENT"])
    [["ALUMNOS","EXISTENTES","EGRESADOS","TITULADOS","DOCENTES"]]
    .sum().reset_index()
    .rename(columns={"ENTIDAD": "CVE_ENT"})
)

# abandono_pct: proxy de permanencia (nota: correlación baja con brecha digital
#   porque el abandono del suroeste ocurre antes de Media Superior)
calidad_ent["abandono_pct"] = (
    (calidad_ent["ALUMNOS"] - calidad_ent["EXISTENTES"]) /
    calidad_ent["ALUMNOS"] * 100
).round(2)

# titulados_pct: indicador de CALIDAD — de cada 100 egresados, cuántos se titulan
# Correlación con brecha digital: r=-0.38 (más desconexión → menos titulación)
# Suroeste promedio: ~5%  |  Nacional: ~12%  |  Norte: ~17%
calidad_ent["titulados_pct"] = (
    calidad_ent["TITULADOS"] / calidad_ent["EGRESADOS"] * 100
).round(2)

print(f"Entidades: {len(calidad_ent)}")
print(calidad_ent[["CVE_ENT","C_NOM_ENT","ALUMNOS","abandono_pct","titulados_pct"]]
      .sort_values("titulados_pct").to_string(index=False))
# Out:
# Entidades: 32
#  CVE_ENT                       C_NOM_ENT  ALUMNOS  abandono_pct  titulados_pct
#       18                         NAYARIT    57435         11.33           3.96
#       20                          OAXACA   151344         10.70           4.24
#        3             BAJA CALIFORNIA SUR    38451         15.72           4.33
#       32                       ZACATECAS    66626         11.91           4.68
#       10                         DURANGO    80264         10.81           4.76
#        7                         CHIAPAS   210290          8.23           5.28
#        9               CIUDAD DE MÃXICO   636213          9.79           5.61
#       12                        GUERRERO   144323          5.47           6.04
#       25                         SINALOA   151470          4.79           6.44
#       21                          PUEBLA   289019          8.00           6.87
#       16            MICHOACÃN DE OCAMPO   172633          9.32           7.15
# ...

# %% [markdown]
# ## 4 · Población + pobreza extrema por entidad — CONEVAL 2020
#
# Se calcula agregando el Concentrado municipal de CONEVAL.
# **Ventaja:** misma fuente que `pobreza_pct` → consistencia total de fuentes.
# La población que CONEVAL usó para sus indicadores es exactamente la que usamos para normalizar.

# %%
coneval_mun = pd.read_excel(
    f"{RAW}/Concentrado_indicadores_de_pobreza_2020.xlsx",
    sheet_name="Concentrado municipal",
    header=4,
    skiprows=[5, 6, 7],
)

# Mapeo de columnas según estructura del archivo CONEVAL
# col 1=CVE_ENT, 2=nom_estado, 7=pob_2020
# col 10=pobreza_pct_2020, 13=pobreza_pers_2020
# col 19=pob_extrema_pct_2020, 22=pob_extrema_pers_2020
coneval_mun = coneval_mun.iloc[:, [1, 2, 7, 10, 13, 19, 22]]
coneval_mun.columns = ["CVE_ENT","nom_estado","pob_2020",
                       "pobreza_pct_mun","pobreza_pers",
                       "pob_extrema_pct_mun","pob_extrema_pers"]

coneval_mun = coneval_mun[
    coneval_mun["CVE_ENT"].astype(str).str.match(r"^\d{2}$")
].copy()
coneval_mun["CVE_ENT"] = coneval_mun["CVE_ENT"].astype(int)
for col in ["pob_2020","pobreza_pers","pob_extrema_pers"]:
    coneval_mun[col] = pd.to_numeric(coneval_mun[col], errors="coerce").fillna(0)

# Agregar a nivel estatal
pob_extrema_est = coneval_mun.groupby("CVE_ENT").apply(lambda g: pd.Series({
    "pob_total":        int(g["pob_2020"].sum()),
    "pob_extrema_pct":  round(g["pob_extrema_pers"].sum() / g["pob_2020"].sum() * 100, 1),
    "pob_extrema_abs":  int(g["pob_extrema_pers"].sum()),
})).reset_index()

pob_estatal = pob_extrema_est[["CVE_ENT","pob_total"]]
POB_MEXICO  = int(pob_estatal["pob_total"].sum())

print(f"Estados procesados : {len(pob_extrema_est)}")
print(f"Población México   : {POB_MEXICO:,}")
print()
print(pob_extrema_est.sort_values("pob_extrema_pct", ascending=False).to_string(index=False))
# Out:
# Estados procesados : 32
# Población México   : 127,409,241
#
#  CVE_ENT  pob_total  pob_extrema_pct  pob_extrema_abs
#        7  5586615.0             28.3        1580754.0
#       12  3661640.0             26.9         984457.0
#       20  4134039.0             24.3        1003615.0
#       30  8343850.0             16.0        1337711.0
#       27  2504927.0             14.0         351295.0
#       21  6497223.0             13.8         897666.0
#        4   978797.0             11.9         116125.0
#       31  2259381.0             11.4         258120.0
#       17  2036707.0              9.6         195187.0
#       24  2874932.0              9.5         273056.0
#       23  1811370.0              9.5         172482.0
#       29  1367993.0              8.8         121028.0
#       16  4748742.0              8.4         399265.0
#       15 18136090.0              8.3        1501956.0
#       13  3054428.0              7.2         221169.0
# ...

# %% [markdown]
# ## 5 · Integración de fuentes

# %%
# Coordenadas de centroides por entidad (para mapa en dashboard)
COORDS = {
    1:(22.0,-102.3), 2:(30.8,-115.6), 3:(25.1,-111.5), 4:(19.1,-90.4),
    5:(27.2,-102.1), 6:(19.1,-104.0), 7:(16.7,-92.9),  8:(28.6,-106.1),
    9:(19.4,-99.1),  10:(24.5,-104.7),11:(20.9,-101.3),12:(17.6,-99.5),
    13:(20.5,-98.9), 14:(20.7,-103.4),15:(19.4,-99.7), 16:(19.6,-101.7),
    17:(18.7,-99.0), 18:(22.0,-105.0),19:(25.6,-99.6), 20:(17.1,-96.7),
    21:(18.9,-97.7), 22:(20.6,-100.0),23:(19.2,-88.5), 24:(22.3,-101.0),
    25:(24.8,-107.4),26:(29.3,-110.7),27:(17.8,-92.7), 28:(24.3,-98.8),
    29:(19.3,-98.2), 30:(19.8,-96.9), 31:(20.7,-89.1), 32:(23.0,-102.5),
}

NOMBRE_CORTO = {
    "Veracruz de Ignacio de la Llave": "Veracruz",
    "Michoacán de Ocampo":             "Michoacán",
    "Ciudad de México":                "CDMX",
    "Baja California Sur":             "B.C. Sur",
    "Coahuila de Zaragoza":            "Coahuila",
    "San Luis Potosí":                 "S.L. Potosí",
}

# Merge: ENDUTIH + CONEVAL pobreza total + CONEVAL pobreza extrema/pob + SEP calidad
estados = (
    internet_ent
    .merge(pobreza[["CVE_ENT","pobreza_pct"]],                        on="CVE_ENT", how="left")
    .merge(pob_extrema_est,                                            on="CVE_ENT", how="left")
    .merge(calidad_ent[["CVE_ENT","abandono_pct","titulados_pct",
                         "ALUMNOS","EXISTENTES"]],                     on="CVE_ENT", how="left")
)

# ── Columnas derivadas ────────────────────────────────────────────────────────
estados["brecha"]   = (100 - estados["internet_pct"]).round(1)
estados["nombre"]   = estados["NOM_ENT"].replace(NOMBRE_CORTO)
estados["lat"]      = estados["CVE_ENT"].map(lambda x: COORDS.get(x,(0,0))[0])
estados["lon"]      = estados["CVE_ENT"].map(lambda x: COORDS.get(x,(0,0))[1])
estados["nodo"]     = estados["CVE_ENT"].isin([7, 12, 20, 30]).astype(int)

# Personas sin internet (valor absoluto real, normalizado por estado)
estados["personas_sin_internet"] = (
    (estados["brecha"] / 100) * estados["pob_total"]
).round(0).astype("Int64")

# Alumnos que abandonaron en valor absoluto
estados["alumnos_abandono_abs"] = (
    estados["ALUMNOS"] - estados["EXISTENTES"]
).round(0).astype("Int64")

print(f"DataFrame final: {estados.shape}")
print()
cols_preview = ["CVE_ENT","nombre","internet_pct","brecha",
                "pobreza_pct","pob_extrema_pct","titulados_pct",
                "personas_sin_internet"]
print(estados.sort_values("internet_pct")[cols_preview].to_string(index=False))
# Out:
# DataFrame final: (32, 18)
#
#  CVE_ENT               nombre  internet_pct  brecha  pobreza_pct  pob_extrema_pct  titulados_pct  personas_sin_internet
#        7              Chiapas          50.7    49.3         74.4             28.3           5.28                2754201
#       20               Oaxaca          55.5    44.5         63.8             24.3           4.24                1839647
#       12             Guerrero          58.9    41.1         65.6             26.9           6.04                1504934
#       29             Tlaxcala          61.5    38.5         58.3              8.8          19.70                 526677
#       21               Puebla          61.8    38.2         63.4             13.8           6.87                2481939
#       10              Durango          63.9    36.1         37.6              4.4           4.76                 668667
# ...

# %% [markdown]
# ## 6 · Exportar CSVs procesados

# %%
# ── estados.csv — un registro por entidad, agrupado por tema ─────────────────
cols_export = [
    # Identificadores
    "CVE_ENT", "NOM_ENT", "nombre",
    # Infraestructura digital
    "internet_pct", "brecha", "personas_sin_internet",
    # Economía
    "pobreza_pct", "pob_extrema_pct", "pob_extrema_abs",
    # Calidad educativa
    "titulados_pct", "abandono_pct", "alumnos_abandono_abs",
    # Geografía / control
    "lat", "lon", "nodo", "pob_total",
]
estados[cols_export].to_csv(f"{OUT}/estados.csv", index=False, encoding="utf-8")
print(f"✔  datos/estados.csv — {len(estados)} estados · {len(cols_export)} variables")

# ── nacional.csv — indicadores agregados (para value boxes) ──────────────────
pd.DataFrame([{
    "media_nacional": media_nac,
    "pct_urbano":     pct_urbano,
    "pct_rural":      pct_rural,
    "brecha_ur":      round(pct_urbano - pct_rural, 1),
    "pob_mexico":     POB_MEXICO,
}]).to_csv(f"{OUT}/nacional.csv", index=False, encoding="utf-8")
print("✔  datos/nacional.csv")

# ── tendencia_abandono.csv — serie histórica 2019-2024 ───────────────────────
tendencia.to_csv(f"{OUT}/tendencia_abandono.csv", index=False, encoding="utf-8")
print(f"✔  datos/tendencia_abandono.csv — {len(tendencia)} ciclos")

print()
print("Variables exportadas por tema:")
for tema, cols in {
    "Infraestructura digital": ["internet_pct","brecha","personas_sin_internet"],
    "Economía":                ["pobreza_pct","pob_extrema_pct","pob_extrema_abs"],
    "Calidad educativa":       ["titulados_pct","abandono_pct","alumnos_abandono_abs"],
}.items():
    print(f"  {tema}: {', '.join(cols)}")
# Out:
# ✔  datos/estados.csv — 32 estados · 16 variables
# ✔  datos/nacional.csv
# ✔  datos/tendencia_abandono.csv — 5 ciclos
#
# Variables exportadas por tema:
#   Infraestructura digital: internet_pct, brecha, personas_sin_internet
#   Economía: pobreza_pct, pob_extrema_pct, pob_extrema_abs
#   Calidad educativa: titulados_pct, abandono_pct, alumnos_abandono_abs

# %% [markdown]
# ## 7 · Verificación rápida

# %%
import matplotlib.pyplot as plt
import matplotlib
matplotlib.rcParams["font.family"] = "sans-serif"

fig, axes = plt.subplots(1, 3, figsize=(16, 5))
fig.patch.set_facecolor("#f8fafc")

SUROESTE = [7, 12, 20]
paleta   = estados["CVE_ENT"].apply(
    lambda x: "#c0392b" if x in SUROESTE else "#94a3b8"
)

for ax, (col, label) in zip(axes, [
    ("internet_pct",   "Hogares con internet (%) — ENDUTIH 2024"),
    ("pob_extrema_pct","Pobreza extrema (%) — CONEVAL 2020"),
    ("titulados_pct",  "Titulación Media Superior (%) — SEP 2023-24"),
]):
    df_s = estados.sort_values(col)
    ax.barh(df_s["nombre"], df_s[col],
            color=df_s["CVE_ENT"].apply(lambda x: "#c0392b" if x in SUROESTE else "#94a3b8"),
            height=0.75, edgecolor="white", linewidth=0.3)
    ax.axvline(df_s[col].mean(), color="#1d4ed8", linestyle="--",
               linewidth=1, alpha=0.7)
    ax.set_xlabel(label, fontsize=8)
    ax.set_facecolor("#f8fafc")
    ax.tick_params(axis="y", labelsize=7)
    ax.grid(axis="x", alpha=0.3, linewidth=0.5)

from matplotlib.patches import Patch
fig.legend(
    handles=[Patch(facecolor="#c0392b",label="Suroeste (Chis/Gro/Oax)"),
             Patch(facecolor="#94a3b8",label="Resto del país")],
    loc="lower center", ncol=2, fontsize=9, bbox_to_anchor=(0.5,-0.04)
)
fig.suptitle("Verificación de datos procesados", fontsize=12, fontweight="bold")
plt.tight_layout()
plt.savefig(f"{OUT}/verificacion_datos.png", dpi=120, bbox_inches="tight")
plt.show()
print("✔  Verificación visual guardada")
# Out:
# ✔  Verificación visual guardada
